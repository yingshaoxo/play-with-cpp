// %% [markdown]
// https://leetcode.com/problems/subtree-of-another-tree
//
//
//
// Runtime: 28 ms, faster than 92.94% of C++ online submissions for Subtree of Another Tree.
// Memory Usage: 29.8 MB, less than 26.77% of C++ online submissions for Subtree of Another Tree.
//
//
//
// ```cpp
// /**
//  * Definition for a binary tree node.
//  * struct TreeNode {
//  *     int val;
//  *     TreeNode *left;
//  *     TreeNode *right;
//  *     TreeNode() : val(0), left(nullptr), right(nullptr) {}
//  *     TreeNode(int x) : val(x), left(nullptr), right(nullptr) {}
//  *     TreeNode(int x, TreeNode *left, TreeNode *right) : val(x), left(left), right(right) {}
//  * };
//  */
// class Solution {
// public:
//     bool is_end(TreeNode* node) {
//         if (node != nullptr) {
//             if ((node->left == nullptr) && (node->right == nullptr)) {
//                 return true;
//             }
//         }
//         return false;
//     }
//
//     bool compare(TreeNode* a, TreeNode* b) {
//         if ((a == nullptr) && (b == nullptr)) {
//             return true;
//         } else {
//            if ((a != nullptr) && (b != nullptr)) {
//                if (a->val == b->val) {
//                    if (is_end(a) && is_end(b)) {
//                        return true;
//                    }
//                    return compare(a->left, b->left) && compare(a->right, b->right);
//                } else {
//                    return false;
//                }
//            } else {
//                return false;
//            }
//         }
//     }
//
//     bool travel(TreeNode* node) {
//         if (node == nullptr) {
//             return false;
//         } else {
//             if (compare(node, t)) {
//                 return true;
//             }
//             //printf("%d ", node->val);
//             return travel(node->left) || travel(node->right);
//         }
//     }
//
//     bool isSubtree(TreeNode* s, TreeNode* t) {
//         this->t = t;
//         return travel(s);
//     }
//
// private:
//     TreeNode* t = nullptr;
// };
// ```

// %% [markdown]
// attemps: 10
//
// spent: 2 hours
